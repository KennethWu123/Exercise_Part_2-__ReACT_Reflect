# %%
# Simulatation ReACT WORKFLOW

# -------------------------
# REASONING
# -------------------------
reasoning = """
Create a list of numbers, calculate the average, and print it.
The steps:
1. Make a list, e.g., [10, 20, 30, 40]
2. Compute the sum
3. Divide by the number of items
4. Print the result
"""

print("REASONING:", reasoning)

# -------------------------
# ACTION (Generated Code)
# -------------------------
print("\nACTION: Generating Python code...\n")

code = """
numbers = [10, 20, 30, 40]
average = sum(numbers) / len(numbers)
print("Average:", average)
"""

print(code)

# -------------------------
# OBSERVATION (Run the Code)
# -------------------------
print("OBSERVATION: Running the code...\n")

numbers = [10, 20, 30, 40]
average = sum(numbers) / len(numbers)
print("Average:", average)

# -------------------------
# FINAL ANSWER
# -------------------------
print("\nFINAL ANSWER: Code executed successfully with no errors.")
# Out:
# REASONING:
# Create a list of numbers, calculate the average, and print it.
# The steps:
# 1. Make a list, e.g., [10, 20, 30, 40]
# 2. Compute the sum
# 3. Divide by the number of items
# 4. Print the result
#
#
# ACTION: Generating Python code...
#
#
# numbers = [10, 20, 30, 40]
# average = sum(numbers) / len(numbers)
# print("Average:", average)
#
# OBSERVATION: Running the code...
#
# Average: 25.0
#
# FINAL ANSWER: Code executed successfully with no errors.
